# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
#data = pd.read_csv("E:\Software_files\datasets\IOT-temp.csv" )
data = pd.read_csv("IOT-temp.csv" )

# %%
pd.to_datetime(data['noted_date'], format='%d-%m-%Y %H:%M', utc=True)
#data[["Date","Time"]] = data.noted_date.str.split(' ', expand =True)
# Out:
# 0       2018-12-08 09:30:00+00:00
# 1       2018-12-08 09:30:00+00:00
# 2       2018-12-08 09:29:00+00:00
# 3       2018-12-08 09:29:00+00:00
# 4       2018-12-08 09:29:00+00:00
#                    ...
# 97601   2018-07-28 07:07:00+00:00
# 97602   2018-07-28 07:07:00+00:00
# 97603   2018-07-28 07:06:00+00:00
# 97604   2018-07-28 07:06:00+00:00
# 97605   2018-07-28 07:06:00+00:00
# Name: noted_date, Length: 97606, dtype: datetime64[ns, UTC]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97606 entries, 0 to 97605
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          97606 non-null  object
#  1   room_id/id  97606 non-null  object
#  2   noted_date  97606 non-null  object
#  3   temp        97606 non-null  int64
#  4   out/in      97606 non-null  object
#  5   Date        97606 non-null  object
#  6   Time        97606 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.2+ MB

# %%
data.head()
# Out:
#                                     id  room_id/id        noted_date  temp  \
# 0  __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30    29
# 1  __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30    29
# 2  __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29    41
# 3  __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29    41
# 4  __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29    31
#
#   out/in        Date   Time
# 0     In  08-12-2018  09:30
# 1     In  08-12-2018  09:30
# 2    Out  08-12-2018  09:29
# 3    Out  08-12-2018  09:29
# 4     In  08-12-2018  09:29

# %%
data[["Date","Time"]] = data.noted_date.str.split(' ', expand =True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97606 entries, 0 to 97605
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          97606 non-null  object
#  1   room_id/id  97606 non-null  object
#  2   noted_date  97606 non-null  object
#  3   temp        97606 non-null  int64
#  4   out/in      97606 non-null  object
#  5   Date        97606 non-null  object
#  6   Time        97606 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.2+ MB

# %%
# plt.plot(data['Date'], data['temp'])
data[['Time','temp']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.iloc[0:604].plot.scatter(x='Time',y='temp')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='temp'>
