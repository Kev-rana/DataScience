# %%
import pandas as pd
import numpy as np
import seaborn as sns
#covid_data = pd.read_csv("COVID-19-Activity.csv" )
covid_data = pd.read_csv("~/software_files/datasets/COVID-19-Activity.csv" )

# %%
covid_data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME REPORT_DATE  \
# 0                        57226         NaN                 NaN  2020-11-06
# 1                           41         NaN                 NaN  2020-03-18
# 2                          423         NaN                 NaN  2020-05-23
# 3                          391         NaN                 NaN  2020-05-19
# 4                        44299         NaN                 NaN  2020-10-11
#
#   CONTINENT_NAME            DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  \
# 0           Asia  JHU CSSE Global Timeseries                       3
# 1           Asia  JHU CSSE Global Timeseries                       0
# 2           Asia  JHU CSSE Global Timeseries                       1
# 3           Asia  JHU CSSE Global Timeseries                       0
# 4           Asia  JHU CSSE Global Timeseries                       3
#
#    COUNTY_FIPS_NUMBER COUNTRY_ALPHA_3_CODE  COUNTRY_SHORT_NAME  \
# ...

# %%
#data cleaning
##county name, PROVINCE STATE_NAME is not required forthis analysis, hence delete it
del covid_data['COUNTY_NAME']
del covid_data['PROVINCE_STATE_NAME']
covid_data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 0                        57226  2020-11-06           Asia
# 1                           41  2020-03-18           Asia
# 2                          423  2020-05-23           Asia
# 3                          391  2020-05-19           Asia
# 4                        44299  2020-10-11           Asia
#
#              DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER  \
# 0  JHU CSSE Global Timeseries                       3                 NaN
# 1  JHU CSSE Global Timeseries                       0                 NaN
# 2  JHU CSSE Global Timeseries                       1                 NaN
# 3  JHU CSSE Global Timeseries                       0                 NaN
# 4  JHU CSSE Global Timeseries                       3                 NaN
#
#   COUNTRY_ALPHA_3_CODE  COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  \
# 0                  PSE  West Bank and Gaza                   PS
# ...

# %%
#statistical analysis
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1381770 entries, 0 to 1381769
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   PEOPLE_POSITIVE_CASES_COUNT      1381770 non-null  int64
#  1   REPORT_DATE                      1381770 non-null  object
#  2   CONTINENT_NAME                   1380990 non-null  object
#  3   DATA_SOURCE_NAME                 1381770 non-null  object
#  4   PEOPLE_DEATH_NEW_COUNT           1381770 non-null  int64
#  5   COUNTY_FIPS_NUMBER               1255020 non-null  float64
#  6   COUNTRY_ALPHA_3_CODE             1380990 non-null  object
#  7   COUNTRY_SHORT_NAME               1381770 non-null  object
#  8   COUNTRY_ALPHA_2_CODE             1380600 non-null  object
#  9   PEOPLE_POSITIVE_NEW_CASES_COUNT  1381770 non-null  int64
#  10  PEOPLE_DEATH_COUNT               1381770 non-null  int64
# ...

# %%
covid_data.describe()
# Out:
#        PEOPLE_POSITIVE_CASES_COUNT  PEOPLE_DEATH_NEW_COUNT  \
# count                 1.381770e+06            1.381770e+06
# mean                  8.636125e+03            1.732243e+00
# std                   1.417873e+05            2.699316e+01
# min                   0.000000e+00           -1.918000e+03
# 25%                   5.000000e+00            0.000000e+00
# 50%                   1.690000e+02            0.000000e+00
# 75%                   1.133000e+03            0.000000e+00
# max                   1.090494e+07            4.143000e+03
#
#        COUNTY_FIPS_NUMBER  PEOPLE_POSITIVE_NEW_CASES_COUNT  PEOPLE_DEATH_COUNT
# count        1.255020e+06                     1.381770e+06        1.381770e+06
# mean         3.147197e+04                     7.858043e+01        2.285484e+02
# std          1.636533e+04                     1.337798e+03        3.412854e+03
# min          1.001000e+03                    -4.730100e+04        0.000000e+00
# ...

# %%
#countries with most number of cases on say 29th dec
covid_data.loc[covid_data['REPORT_DATE'] == '2020-12-29'].sort_values(by=['PEOPLE_POSITIVE_CASES_COUNT']).tail()
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 1318525                      2382865  2020-12-29         Europe
# 1336944                      2570767  2020-12-29         Europe
# 59663                        3073923  2020-12-29         Europe
# 1258705                      7563551  2020-12-29        America
# 1247084                     10244852  2020-12-29           Asia
#
#                    DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  \
# 1318525  JHU CSSE Global Timeseries                     458
# 1336944  JHU CSSE Global Timeseries                     968
# 59663    JHU CSSE Global Timeseries                     548
# 1258705  JHU CSSE Global Timeseries                    1111
# 1247084  JHU CSSE Global Timeseries                     286
#
#          COUNTY_FIPS_NUMBER COUNTRY_ALPHA_3_CODE COUNTRY_SHORT_NAME  \
# 1318525                 NaN                  GBR     United Kingdom
# 1336944                 NaN                  FRA             France
# ...

# %%
covid_data['REPORT_DATE'] = pd.to_datetime(covid_data['REPORT_DATE'])
#covid_data.info()
#covid_data.loc[covid_data["COUNTRY_ALPHA_3_CODE"] == 'IND'].plot.scatter(x = (pd.to_datetime('2020-01-01') - covid_data['REPORT_DATE']) % pd.Timedelta(days=365), y ="PEOPLE_POSITIVE_CASES_COUNT" )
#covid_data['day'] = int(covid_data['REPORT_DATE'].str.split(' ').str[0])
#covid_data['day'] = ((pd.to_datetime('2020-01-01') - covid_data['REPORT_DATE']) % pd.Timedelta(days=365)).str.split(' ').str[0]
covid_data['day'] = ((pd.to_datetime('2020-01-01') - covid_data['REPORT_DATE']) % pd.Timedelta(days=365))
#covid_data.info()
covid_data.head()
#(pd.to_datetime('2020-01-01') - covid_data['REPORT_DATE']) / pd.Timedelta(days=365)
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 0                        57226  2020-11-06           Asia
# 1                           41  2020-03-18           Asia
# 2                          423  2020-05-23           Asia
# 3                          391  2020-05-19           Asia
# 4                        44299  2020-10-11           Asia
#
#              DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER  \
# 0  JHU CSSE Global Timeseries                       3                 NaN
# 1  JHU CSSE Global Timeseries                       0                 NaN
# 2  JHU CSSE Global Timeseries                       1                 NaN
# 3  JHU CSSE Global Timeseries                       0                 NaN
# 4  JHU CSSE Global Timeseries                       3                 NaN
#
#   COUNTRY_ALPHA_3_CODE  COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  \
# 0                  PSE  West Bank and Gaza                   PS
# ...

# %%
#covid_data['day'] = covid_data['day'].astype('timedelta64[h]')[0]
#covid_data['day'] = pd.to_timedelta(covid_data['day']).astype(str)
#df['tdColumn'] = df['tdColumn'].dt.days.astype('int16')
#covid_data.loc[covid_data["COUNTRY_ALPHA_3_CODE"] == 'IND'].plot.scatter(x = 'day', y = 'PEOPLE_DEATH_COUNT')
covid_data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 0                        57226  2020-11-06           Asia
# 1                           41  2020-03-18           Asia
# 2                          423  2020-05-23           Asia
# 3                          391  2020-05-19           Asia
# 4                        44299  2020-10-11           Asia
#
#              DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER  \
# 0  JHU CSSE Global Timeseries                       3                 NaN
# 1  JHU CSSE Global Timeseries                       0                 NaN
# 2  JHU CSSE Global Timeseries                       1                 NaN
# 3  JHU CSSE Global Timeseries                       0                 NaN
# 4  JHU CSSE Global Timeseries                       3                 NaN
#
#   COUNTRY_ALPHA_3_CODE  COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  \
# 0                  PSE  West Bank and Gaza                   PS
# ...

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1381770 entries, 0 to 1381769
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   PEOPLE_POSITIVE_CASES_COUNT      1381770 non-null  int64
#  1   REPORT_DATE                      1381770 non-null  datetime64[ns]
#  2   CONTINENT_NAME                   1380990 non-null  object
#  3   DATA_SOURCE_NAME                 1381770 non-null  object
#  4   PEOPLE_DEATH_NEW_COUNT           1381770 non-null  int64
#  5   COUNTY_FIPS_NUMBER               1255020 non-null  float64
#  6   COUNTRY_ALPHA_3_CODE             1380990 non-null  object
#  7   COUNTRY_SHORT_NAME               1381770 non-null  object
#  8   COUNTRY_ALPHA_2_CODE             1380600 non-null  object
#  9   PEOPLE_POSITIVE_NEW_CASES_COUNT  1381770 non-null  int64
#  10  PEOPLE_DEATH_COUNT               1381770 non-null  int64
# ...

# %%
covid_data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 0                        57226  2020-11-06           Asia
# 1                           41  2020-03-18           Asia
# 2                          423  2020-05-23           Asia
# 3                          391  2020-05-19           Asia
# 4                        44299  2020-10-11           Asia
#
#              DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER  \
# 0  JHU CSSE Global Timeseries                       3                 NaN
# 1  JHU CSSE Global Timeseries                       0                 NaN
# 2  JHU CSSE Global Timeseries                       1                 NaN
# 3  JHU CSSE Global Timeseries                       0                 NaN
# 4  JHU CSSE Global Timeseries                       3                 NaN
#
#   COUNTRY_ALPHA_3_CODE  COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  \
# 0                  PSE  West Bank and Gaza                   PS
# ...

# %%
sns.countplot(x = 'PEOPLE_POSITIVE_CASES_COUNT', data = covid_data.loc[covid_data['REPORT_DATE'] == '2020-12-29'])
# Out:
# <AxesSubplot:xlabel='PEOPLE_POSITIVE_CASES_COUNT', ylabel='count'>

# %%
covid_data.corr()
# Out:
#                                  PEOPLE_POSITIVE_CASES_COUNT  \
# PEOPLE_POSITIVE_CASES_COUNT                         1.000000
# PEOPLE_DEATH_NEW_COUNT                              0.590723
# COUNTY_FIPS_NUMBER                                 -0.046997
# PEOPLE_POSITIVE_NEW_CASES_COUNT                     0.624028
# PEOPLE_DEATH_COUNT                                  0.889426
#
#                                  PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER  \
# PEOPLE_POSITIVE_CASES_COUNT                    0.590723           -0.046997
# PEOPLE_DEATH_NEW_COUNT                         1.000000           -0.037410
# COUNTY_FIPS_NUMBER                            -0.037410            1.000000
# PEOPLE_POSITIVE_NEW_CASES_COUNT                0.654944           -0.039899
# PEOPLE_DEATH_COUNT                             0.700956           -0.053472
#
#                                  PEOPLE_POSITIVE_NEW_CASES_COUNT  \
# PEOPLE_POSITIVE_CASES_COUNT                             0.624028
# ...

# %%
sns.heatmap(covid_data[["PEOPLE_POSITIVE_CASES_COUNT", "PEOPLE_DEATH_NEW_COUNT", "PEOPLE_POSITIVE_NEW_CASES_COUNT", "PEOPLE_DEATH_COUNT"]].corr())
# Out:
# <AxesSubplot:>

# %%
covid_data.loc[covid_data["COUNTRY_ALPHA_3_CODE"] == 'IND'].groupby("day").plot()
# Out:
# day
# 0 days      AxesSubplot(0.125,0.125;0.775x0.755)
# 1 days      AxesSubplot(0.125,0.125;0.775x0.755)
# 2 days      AxesSubplot(0.125,0.125;0.775x0.755)
# 3 days      AxesSubplot(0.125,0.125;0.775x0.755)
# 4 days      AxesSubplot(0.125,0.125;0.775x0.755)
#                             ...
# 360 days    AxesSubplot(0.125,0.125;0.775x0.755)
# 361 days    AxesSubplot(0.125,0.125;0.775x0.755)
# 362 days    AxesSubplot(0.125,0.125;0.775x0.755)
# 363 days    AxesSubplot(0.125,0.125;0.775x0.755)
# 364 days    AxesSubplot(0.125,0.125;0.775x0.755)
# Length: 365, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ...
